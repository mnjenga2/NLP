# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
file = open("D:/python/kaggle/uhuru speech.txt")
raw = file.read()
# print(raw)

# %%
sentences = nltk.sent_tokenize(raw)
# for sentence in sentences:
#     print(sentence)
#     print()

# %%
words = nltk.word_tokenize(raw)
fdist = FreqDist(words)

# %%
# nltk.pos_tag(words)

# %%
nltk.FreqDist(words)
# Out:
# FreqDist({'the': 113, ',': 109, '.': 92, 'of': 82, 'and': 80, 'to': 48, 'in': 42, 'a': 34, 'have': 32, 'that': 31, ...})

# %%
stop_words=stopwords.words("english")
add_to_stop_words = ['.', ',', ':', ';', "'", '--', '"', '”', '“']
stop_words.extend(add_to_stop_words)
# print(stop_words)

# %%
for i in stop_words:
    if i in words:
        while i in words:
            words.remove(i)

# %%
nltk.FreqDist(words)
# Out:
# FreqDist({'I': 19, 'must': 15, 'corruption': 14, 'Corruption': 13, 'We': 11, 'Kenya': 10, 'Ladies': 9, 'Public': 9, 'Government': 9, 'Gentlemen': 8, ...})

# %%
text = nltk.Text(words)
words = [w.lower() for w in text]
nltk.FreqDist(text)
# Out:
# FreqDist({'I': 19, 'must': 15, 'corruption': 14, 'Corruption': 13, 'We': 11, 'Kenya': 10, 'Ladies': 9, 'Public': 9, 'Government': 9, 'Gentlemen': 8, ...})

# %%
fdist = FreqDist(words)
fdist.plot(30, cumulative=False)
plt.show()

# %%
# Generate a word cloud image

from wordcloud import WordCloud

speech_wordcloud = WordCloud(width=600, height=400).generate(raw)
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(speech_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
